# %% [markdown]
# Extract concepts and tasks from all papers, and harmonize these for further processing.

# %%
from pathlib import Path
from ontology_learner.lit_mining.paperResults import PaperResults
import json
import hashlib

# %% [markdown]
# Get all of the processed outputs from inital paper annotation by GPT-4.

# %%
datadir = Path('/Users/poldrack/data_unsynced/ontology-learner/data/json')
outdir_fulltext = Path('/Users/poldrack/Dropbox/data/ontology-learner/data/results_fulltext')

results = PaperResults(results_dir=outdir_fulltext, output_dir=outdir_fulltext)
results.get_results_files()
results.parse_results_files()
# Out:
# found 10235 results files

# %% [markdown]
# create a dict that maps tasks to pmcids

# %%
taskinfo = {}
for task in results.tasks:
    hash = hashlib.md5(task.encode('utf-8')).hexdigest()
    taskinfo[hash] = results.
# Out:
# 24145

# %%
results.paper_results
# Out:
# {'9317210': {'construct': ['resting state brain dynamics',
#    'functional connectivity',
#    'network topology',
#    'variance of the BOLD signal',
#    'fractional amplitude of low frequency fluctuation (fALFF)',
#    'Hurst exponent'],
#   'task': ['Resting state fMRI'],
#   'condition': {'Resting state fMRI': ['eyes closed in darkness (CID)',
#     'eyes open in darkness (OID)',
#     'eyes closed in light (CIL)',
#     'eyes open in light (OIL)']},
#   'contrast': {'Resting state fMRI': ['eyes open vs. eyes closed',
#     'eyes open in darkness vs. eyes closed in darkness',
#     'eyes open in light vs. eyes closed in light']},
#   'brain_region': {'Resting state fMRI': ['primary and secondary sensory cortical areas',
#     'insula',
#     'thalamus',
#     'posterior cingulate cortex (PCC)',
#     'bilateral perisylvian and perirolandic regions',
#     'visual cortex',
#     'somatosensory cortex',
#     'auditory systems',
#     'default mode network (DMN)',
# ...
